# %%
#local scope
def add():
    x=5#local variable
    x=x+5
    print(x)
add()
print(x)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5     print(x)
#       6 add()
# ----> 7 print(x)
#
# NameError: name 'x' is not defined

# %%
#global scope
x=5
def add():
   # x=x+1
    return x
print(add())
#x=x+1
#print(x)
# Out:
# 5
